# %% [markdown]
# # Python Set Type
#
# A set is an unordered collection of unique elements in Python. Sets are mutable, meaning their contents can be changed after they are created. Sets are created using curly braces `{}` or the `set()` constructor.

# %% [markdown]
# ## Creating a Set
#
# To create a set, you can use curly braces `{}` with comma-separated values inside or the `set()` constructor with a list as an argument. Here are some examples:

# %%
setA = {4, 5, 6, 1, 1, 2, 1}

# %%
type(setA)
# Out:
# set

# %%
print(setA)
# Out:
# {1, 2, 4, 5, 6}

# %%
set(["mississippi", "LosAngles"])
# Out:
# {'LosAngles', 'mississippi'}

# %% [markdown]
# # Set Modification

# %%
setA
# Out:
# {1, 2, 4, 5, 6}

# %%
setA.add(9)

# %%
setA
# Out:
# {1, 2, 3, 4, 5, 6, 9, 'ram'}

# %%
setA.update([4,6,7])

# %%
setA
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 'ram'}

# %%
setA.pop()
# Out:
# 1

# %%
setA
# Out:
# {2, 3, 4, 5, 6, 7, 9, 'ram'}

# %%
setA.remove("ram")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 setA.remove("ram")
#
# KeyError: 'ram'

# %%
setA.discard(9)

# %%
setA
# Out:
# {2, 3, 4, 5, 6, 7}

# %% [markdown]
# ## Set Operations
#
# Docs : https://www.w3schools.com/python/python_ref_set.asp
#
# Sets in Python support a variety of operations, including union, intersection, difference, and symmetric difference. Here are some examples:

# %%
A = {1,2,3,4,5,6}
B = {5,6,7,8,9}

# %%
aUb = A.union(B) # |
aUb
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
aNb = A.intersection(B) # &
aNb
# Out:
# {5, 6}

# %%
b_a = A.difference(B) # -
b_a
# Out:
# {1, 2, 3, 4}

# %%
A.symmetric_difference(B) # ^
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
setX = set("kangroo")
setY = set("ostrise")

# %%
setX.intersection_update(setY) # setY &= setX
setX

# %%
setX.isdisjoint(setY)
# Out:
# False

# %%
A = {1,2,3,4,5,6,7,8,9}
B = {5,6,7,8}

# %%
B.issuperset(A) # B >= A
# Out:
# False

# %%
B.issubset(A) # B <= A
# Out:
# True
