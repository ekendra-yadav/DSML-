# %%
import pandas as pd
import numpy as np
import nltk
import re
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
dataset = pd.read_csv("IMDB Dataset.csv")
dataset.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
dataset.loc[128,].review
# Out:
# "This movie was one of the best movies that I have seen this year. I didn't see any cameos in the movie, but it is still pretty good. It is similar to Anchorman in the humor department, but I think this is a better put together movie. It actually has a point. If you are going to see a whole bunch of T&A you will be disappointed. Just a well put together movie!!!! If you have nothing to do for the day or you need a lot of humor, you will find this to be a really good movie. I definitely think that Ebert and Roeper's review of this movie is right on. I mean, I don't really like Ebert on most movies, but this is the movie that I will agree about. The movie contains a good enough story that it is actually believable that these type of people are out there. There is definitely something to be said about how they treat virginity in this movie. Yea, sure, you get laughed at when it is found out about, but it still suggests that you wait. Steve did a wonderful job of portraying the person that he did in this movie and yet, it is still funny."

# %%
# Initial Data Processing
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
# Checking duplicate
dataset.drop_duplicates(keep="first", inplace=True)

# %%
dataset.shape
# Out:
# (49582, 2)

# %%
dataset.sentiment.value_counts()
# Out:
# sentiment
# positive    24884
# negative    24698
# Name: count, dtype: int64

# %%
labels = {"negative" : 0, "positive" : 1}

# Feature and Target
X = dataset.review
Y = dataset.sentiment

target = Y.replace(labels).to_numpy()
# Out:
# /tmp/ipykernel_191771/283642269.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   target = Y.replace(labels).to_numpy()

# %%
target
# Out:
# array([1, 1, 1, ..., 0, 0, 0], shape=(49582,))

# %% [markdown]
# ## Text Processing

# %%
def text_processor(text):
    text = text.lower()

    # Removing urls 
    text = re.sub(r'(https?://\S+|www\.\S+)', "", text)
    # Removing HTML Tags
    text = re.sub(r"<.*?>", "", text)
    # Puncuation and special Char
    text = re.sub(r"[^\w\d\s]", " ", text)
    # Remove spaces
    text = text.strip()

    # Stopwords
    text = [word for word in text.split() if word not in ENGLISH_STOP_WORDS]
    text = " ".join(text)
    
    # Lemmatization
    text = lemmatizer.lemmatize(text)

    # Removing single letter from sentence
    text = re.sub(r"\s\w{1}\s", "", text)

    return text

# %%
cleaned_feature = X.apply(text_processor).to_numpy()

# %%
cleaned_feature[0]
# Out:
# 'reviewers mentioned watching justoz episode ll hooked right exactly happened thing struck oz brutality unflinching scenes violence set right word trust faint hearted timid pulls punches regards drugs sex violence hardcore classic use word called oz nickname given oswald maximum security state penitentary focuses mainly emerald city experimental section prison cells glass fronts face inwards privacy high agenda em city home aryans muslims gangstas latinos christians italians irish scuffles death stares dodgy dealings shady agreements far away say main appeal fact goes shows wouldndare forget pretty pictures painted mainstream audiences forget charm forget romance oz doesnmess episode saw struck nasty surreal couldnsay ready watched developed taste oz got accustomed high levels graphic violence just violence injustice crooked guards ll sold nickel inmates ll kill order away mannered middle class inmates turned prison bitches lack street skills prison experience watching oz comfortable uncomfortable viewing thats touch darker'

# %%
# Visualization

#!pip install wordcloud

from wordcloud import WordCloud

cloud = WordCloud(
    colormap="winter", max_words=100, width=500, height=300
)

pos_reviews = cleaned_feature[target == 1]
image = cloud.generate(" ".join(pos_reviews))

plt.imshow(image)

# %% [markdown]
# ## Vectorize or Embeddings

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec

# %%
# Tfidf Vectorizer
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(cleaned_feature)

# %%
X_tfidf[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]], shape=(1, 253999))

# %%
# Word2Vec
tokens = [docs.split() for docs in cleaned_feature]

w2v_model = Word2Vec(
    sentences= tokens,
    vector_size= 200,
    window=4,
    min_count=2
)

# %%
# Word2Vec from Gensim

from gensim import downloader

google_word2vec_model = downloader.load("word2vec-google-news-300")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 5
#       1 # Word2Vec from Gensim
#       3 from gensim import downloader
# ----> 5 google_word2vec_model = downloader.load("word2vec-google-news-300")
#
# File ~/Desktop/education/.venv/lib/python3.12/site-packages/gensim/downloader.py:503, in load(name, return_path)
#     501 sys.path.insert(0, BASE_DIR)
#     502 module = __import__(name)
# --> 503 return module.load_data()
#
# File ~/gensim-data/word2vec-google-news-300/__init__.py:8, in load_data()
#       6 def load_data():
#       7     path = os.path.join(base_dir, 'word2vec-google-news-300', "word2vec-google-news-300.gz")
# ----> 8     model = KeyedVectors.load_word2vec_format(path, binary=True)
#       9     return model
#
# File ~/Desktop/education/.venv/lib/python3.12/site-packages/gensim/models/keyedvectors.py:1721, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1674 @classmethod
#    1675 def load_word2vec_format(
#    1676         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1677         limit=None, datatype=REAL, no_header=False,
#    1678     ):
#    1679     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1680
#    1681     Warnings
#    (...)   1719
#    1720     """
# -> 1721     return _load_word2vec_format(
#    1722         cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1723         limit=limit, datatype=datatype, no_header=no_header,
#    1724     )
#
# File ~/Desktop/education/.venv/lib/python3.12/site-packages/gensim/models/keyedvectors.py:2067, in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2064 kv = cls(vector_size, vocab_size, dtype=datatype)
#    2066 if binary:
# -> 2067     _word2vec_read_binary(
#    2068         fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding
#    2069     )
#    2070 else:
#    2071     _word2vec_read_text(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#
# File ~/Desktop/education/.venv/lib/python3.12/site-packages/gensim/models/keyedvectors.py:1962, in _word2vec_read_binary(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding)
#    1960 new_chunk = fin.read(binary_chunk_size)
#    1961 chunk += new_chunk
# -> 1962 processed_words, chunk = _add_bytes_to_kv(
#    1963     kv, counts, chunk, vocab_size, vector_size, datatype, unicode_errors, encoding)
#    1964 tot_processed_words += processed_words
#    1965 if len(new_chunk) < binary_chunk_size:
#
# File ~/Desktop/education/.venv/lib/python3.12/site-packages/gensim/models/keyedvectors.py:1945, in _add_bytes_to_kv(kv, counts, chunk, vocab_size, vector_size, datatype, unicode_errors, encoding)
#    1943 word = word.lstrip('\n')
#    1944 vector = frombuffer(chunk, offset=i_vector, count=vector_size, dtype=REAL).astype(datatype)
# -> 1945 _add_word_to_kv(kv, counts, word, vector, vocab_size)
#    1946 start = i_vector + bytes_per_vector
#    1947 processed_words += 1
#
# File ~/Desktop/education/.venv/lib/python3.12/site-packages/gensim/models/keyedvectors.py:1913, in _add_word_to_kv(kv, counts, word, weights, vocab_size)
#    1911     logger.warning("duplicate word '%s' in word2vec file, ignoring all but first", word)
#    1912     return
# -> 1913 word_id = kv.add_vector(word, weights)
#    1915 if counts is None:
#    1916     # Most common scenario: no vocab file given. Just make up some bogus counts, in descending order.
#    1917     # TODO (someday): make this faking optional, include more realistic (Zipf-based) fake numbers.
#    1918     word_count = vocab_size - word_id
#
# File ~/Desktop/education/.venv/lib/python3.12/site-packages/gensim/models/keyedvectors.py:526, in KeyedVectors.add_vector(self, key, vector)
#     523         mean = matutils.unitvec(mean).astype(REAL)
#     524     return mean
# --> 526 def add_vector(self, key, vector):
#     527     """Add one new vector at the given key, into existing slot if available.
#     528
#     529     Warning: using this repeatedly is inefficient, requiring a full reallocation & copy,
#    (...)    545
#     546     """
#     547     target_index = self.next_index
#
# KeyboardInterrupt:

# %%
def vectorize( tokens, model):
    vectors = [
        model[word] for word in tokens if word in model
    ]
    if len(vectors) == 0:
        return np.zeros(model.vector_size)

    return np.mean(vectors, axis =0)

embeddings = np.array([
    vectorize(token, w2v_model.wv) for token in tokens
])

# %%
embeddings.shape
# Out:
# (49582, 200)

# %% [markdown]
# ## Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(
    embeddings, target, test_size=0.2, stratify=target, shuffle=True, random_state = 99
)

# model
log_reg = LogisticRegression(max_iter=500, random_state=99)
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500, random_state=99)

# %%
# model #2
svc = SVC(random_state=99)
svc.fit(X_train, y_train)
# Out:
# SVC(random_state=99)

# %%
def evaluate(X_test, y_test, model):
    y_pred= model.predict(X_test)

    cm = confusion_matrix(y_pred, y_test)

    f1 = f1_score(y_pred, y_test)

    acc = accuracy_score(y_pred, y_test)

    print(f"Confision matrix \n {cm}")
    print(f"Accuracy Score : {acc}")
    print(f"F1 Score: {f1}")

# %%
evaluate(
    X_test, y_test, model = log_reg
)
# Out:
# Confision matrix
#  [[4204  614]
#  [ 736 4363]]
# Accuracy Score : 0.8638701220127054
# F1 Score: 0.8660182612147678

# %%
evaluate(
    X_test, y_test, model = svc
)
# Out:
# Confision matrix
#  [[4214  602]
#  [ 726 4375]]
# Accuracy Score : 0.866088534839165
# F1 Score: 0.8682278229807502

# %% [markdown]
# # Saving The model

# %%
import pickle

# %%
to_save = {
    "embeddings" : w2v_model,
    "classifier" : svc
}

with open("sentiment_classifier.pkl", "wb") as f:
    pickle.dump(to_save, f)

# %% [markdown]
# ![image.png](attachment:a59f3d2f-1a9c-4bc9-a064-fc5698c982e5.png)
